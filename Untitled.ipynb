# %%
# %pip install llama_index
# Out:
# Requirement already satisfied: llama_index in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (0.10.5)
# Requirement already satisfied: llama-index-agent-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama_index) (0.1.1)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama_index) (0.10.37)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama_index) (0.1.1)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama_index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama_index) (0.1.1)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama_index) (0.1.1)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama_index) (0.1.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama_index) (0.1.1)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama_index) (0.1.3)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.0->llama_index) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (0.26.0)
# Requirement already satisfied: jsonpath-ng<2.0.0,>=1.6.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (1.6.1)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (3.8.1)
# Requirement already satisfied: numpy in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (1.26.3)
# Requirement already satisfied: openai>=1.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (1.12.0)
# Requirement already satisfied: pandas in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (2.31.0)
# Requirement already satisfied: spacy<4.0.0,>=3.7.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (3.7.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (4.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama_index) (1.14.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama_index) (4.12.3)
# Requirement already satisfied: bs4<0.0.3,>=0.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama_index) (0.0.2)
# Requirement already satisfied: pymupdf<2.0.0,>=1.23.21 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama_index) (1.23.22)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama_index) (4.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama_index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama_index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama_index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.0->llama_index) (2.5)
# Requirement already satisfied: ply in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from jsonpath-ng<2.0.0,>=1.6.0->llama-index-core<0.11.0,>=0.10.0->llama_index) (3.11)
# Requirement already satisfied: pydantic>=1.10 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.0->llama_index) (2.6.1)
# Requirement already satisfied: anyio in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama_index) (4.2.0)
# Requirement already satisfied: certifi in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama_index) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.0.3)
# Requirement already satisfied: idna in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama_index) (3.4)
# Requirement already satisfied: sniffio in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.0->llama_index) (0.14.0)
# Requirement already satisfied: click in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.9.0)
# Requirement already satisfied: PyMuPDFb==1.23.22 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.0->llama_index) (1.23.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msamwelmollel\appdata\roaming\python\python310\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.0->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.26.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (6.4.0)
# Requirement already satisfied: jinja2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (3.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.0->llama_index) (3.0.3)
# Requirement already satisfied: colorama in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.0->llama_index) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama_index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama_index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama_index) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.0->llama_index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.0->llama_index) (2.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.0->llama_index) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from jinja2->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama_index) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install llama-index
# %pip install llama-index-core
# %pip install llama-index-embeddings-openai
# %pip install llama-index-postprocessor-flag-embedding-reranker
# %pip install git+https://github.com/FlagOpen/FlagEmbedding.git
# %pip install llama-parse
# Out:
# Requirement already satisfied: llama-index in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (0.10.5)
# Requirement already satisfied: llama-index-agent-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index) (0.10.37)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (0.26.0)
# Requirement already satisfied: jsonpath-ng<2.0.0,>=1.6.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.6.1)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (3.8.1)
# Requirement already satisfied: numpy in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.26.3)
# Requirement already satisfied: openai>=1.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.12.0)
# Requirement already satisfied: pandas in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (2.31.0)
# Requirement already satisfied: spacy<4.0.0,>=3.7.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (3.7.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (4.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.14.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (4.12.3)
# Requirement already satisfied: bs4<0.0.3,>=0.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (0.0.2)
# Requirement already satisfied: pymupdf<2.0.0,>=1.23.21 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (1.23.22)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (4.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (2.5)
# Requirement already satisfied: ply in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from jsonpath-ng<2.0.0,>=1.6.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.11)
# Requirement already satisfied: pydantic>=1.10 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.6.1)
# Requirement already satisfied: anyio in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (4.2.0)
# Requirement already satisfied: certifi in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.0.3)
# Requirement already satisfied: idna in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.4)
# Requirement already satisfied: sniffio in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (0.14.0)
# Requirement already satisfied: click in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.9.0)
# Requirement already satisfied: PyMuPDFb==1.23.22 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (1.23.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msamwelmollel\appdata\roaming\python\python310\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.26.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (6.4.0)
# Requirement already satisfied: jinja2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.0.3)
# Requirement already satisfied: colorama in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama-index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama-index) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.0->llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from jinja2->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-core in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (0.10.37)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (0.26.0)
# Requirement already satisfied: jsonpath-ng<2.0.0,>=1.6.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (1.6.1)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (3.8.1)
# Requirement already satisfied: numpy in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (1.26.3)
# Requirement already satisfied: openai>=1.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (1.12.0)
# Requirement already satisfied: pandas in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (2.31.0)
# Requirement already satisfied: spacy<4.0.0,>=3.7.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (3.7.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (4.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core) (1.14.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (4.0.3)
# Requirement already satisfied: ply in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from jsonpath-ng<2.0.0,>=1.6.0->llama-index-core) (3.11)
# Requirement already satisfied: pydantic>=1.10 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core) (2.6.1)
# Requirement already satisfied: anyio in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core) (4.2.0)
# Requirement already satisfied: certifi in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core) (1.0.3)
# Requirement already satisfied: idna in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core) (3.4)
# Requirement already satisfied: sniffio in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: click in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core) (8.1.7)
# Requirement already satisfied: joblib in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from openai>=1.1.0->llama-index-core) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msamwelmollel\appdata\roaming\python\python310\site-packages (from requests>=2.31.0->llama-index-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from requests>=2.31.0->llama-index-core) (1.26.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (6.4.0)
# Requirement already satisfied: jinja2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core) (3.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.0.3)
# Requirement already satisfied: colorama in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from dataclasses-json->llama-index-core) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from anyio->httpx->llama-index-core) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core) (2.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.7.1->llama-index-core) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.7.1->llama-index-core) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.7.1->llama-index-core) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from jinja2->spacy<4.0.0,>=3.7.1->llama-index-core) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-embeddings-openai in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (0.1.1)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-embeddings-openai) (0.10.37)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.26.0)
# Requirement already satisfied: jsonpath-ng<2.0.0,>=1.6.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.6.1)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.8.1)
# Requirement already satisfied: numpy in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.26.3)
# Requirement already satisfied: openai>=1.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.12.0)
# Requirement already satisfied: pandas in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.31.0)
# Requirement already satisfied: spacy<4.0.0,>=3.7.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.7.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.14.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.0.3)
# Requirement already satisfied: ply in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from jsonpath-ng<2.0.0,>=1.6.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.11)
# Requirement already satisfied: pydantic>=1.10 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.6.1)
# Requirement already satisfied: anyio in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.2.0)
# Requirement already satisfied: certifi in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.3)
# Requirement already satisfied: idna in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.4)
# Requirement already satisfied: sniffio in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: click in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msamwelmollel\appdata\roaming\python\python310\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.26.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.4.0)
# Requirement already satisfied: jinja2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.0.3)
# Requirement already satisfied: colorama in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from jinja2->spacy<4.0.0,>=3.7.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-postprocessor-flag-embedding-reranker in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (0.1.3)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.35 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-postprocessor-flag-embedding-reranker) (0.10.37)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.35->llama-index-postprocessor-flag-embedding-reranker) (2.0.27)
# ...
# Requirement already satisfied: pytz>=2020.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->datasets->FlagEmbedding==1.2.9) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->datasets->FlagEmbedding==1.2.9) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from scikit-learn->sentence_transformers->FlagEmbedding==1.2.9) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from scikit-learn->sentence_transformers->FlagEmbedding==1.2.9) (3.3.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from sympy->torch>=1.6.0->FlagEmbedding==1.2.9) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets->FlagEmbedding==1.2.9) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/FlagOpen/FlagEmbedding.git 'C:\Users\msamwelmollel\AppData\Local\Temp\pip-req-build-nrzzv6r8'
# Requirement already satisfied: llama-parse in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (0.4.3)
# Requirement already satisfied: llama-index-core>=0.10.29 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-parse) (0.10.37)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core>=0.10.29->llama-parse) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (0.26.0)
# Requirement already satisfied: jsonpath-ng<2.0.0,>=1.6.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (1.6.1)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (3.8.1)
# Requirement already satisfied: numpy in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (1.26.3)
# Requirement already satisfied: openai>=1.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (1.12.0)
# Requirement already satisfied: pandas in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (2.31.0)
# Requirement already satisfied: spacy<4.0.0,>=3.7.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (3.7.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (4.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llama-index-core>=0.10.29->llama-parse) (1.14.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (4.0.3)
# Requirement already satisfied: ply in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from jsonpath-ng<2.0.0,>=1.6.0->llama-index-core>=0.10.29->llama-parse) (3.11)
# Requirement already satisfied: pydantic>=1.10 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core>=0.10.29->llama-parse) (2.6.1)
# Requirement already satisfied: anyio in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (4.2.0)
# Requirement already satisfied: certifi in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (1.0.3)
# Requirement already satisfied: idna in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (3.4)
# Requirement already satisfied: sniffio in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from httpcore==1.*->httpx->llama-index-core>=0.10.29->llama-parse) (0.14.0)
# Requirement already satisfied: click in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core>=0.10.29->llama-parse) (8.1.7)
# Requirement already satisfied: joblib in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core>=0.10.29->llama-parse) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core>=0.10.29->llama-parse) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from openai>=1.1.0->llama-index-core>=0.10.29->llama-parse) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msamwelmollel\appdata\roaming\python\python310\site-packages (from requests>=2.31.0->llama-index-core>=0.10.29->llama-parse) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from requests>=2.31.0->llama-index-core>=0.10.29->llama-parse) (1.26.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (6.4.0)
# Requirement already satisfied: jinja2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (3.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core>=0.10.29->llama-parse) (3.0.3)
# Requirement already satisfied: colorama in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core>=0.10.29->llama-parse) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core>=0.10.29->llama-parse) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from dataclasses-json->llama-index-core>=0.10.29->llama-parse) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core>=0.10.29->llama-parse) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core>=0.10.29->llama-parse) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pandas->llama-index-core>=0.10.29->llama-parse) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from anyio->httpx->llama-index-core>=0.10.29->llama-parse) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core>=0.10.29->llama-parse) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core>=0.10.29->llama-parse) (2.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core>=0.10.29->llama-parse) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msamwelmollel\anaconda3\envs\python310\lib\site-packages (from jinja2->spacy<4.0.0,>=3.7.1->llama-index-core>=0.10.29->llama-parse) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# llama-parse is async-first, running the async code in a notebook requires the use of nest_asyncio
import nest_asyncio

nest_asyncio.apply()

import os

# API access to llama-cloud
os.environ["LLAMA_CLOUD_API_KEY"] = "llx-SyHQUKzf4guxK5aU1QnzURVVl4sbQ4pqX5QzFh7SXhytaj8N"

# Using OpenAI API for embeddings/llms
os.environ["OPENAI_API_KEY"] = "sk-proj-Q0eWC0bJfIIaLkIGOaHOT3BlbkFJcAPgSc2VZCGKEPVJVtzI"

# %%
from llama_index.llms.openai import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from llama_index.llms.openai import OpenAI
#
# File ~\anaconda3\envs\python310\lib\site-packages\llama_index\llms\openai\__init__.py:1
# ----> 1 from llama_index.llms.openai.base import AsyncOpenAI, OpenAI, SyncOpenAI, Tokenizer
#       3 __all__ = ["OpenAI", "Tokenizer", "SyncOpenAI", "AsyncOpenAI"]
#
# File ~\anaconda3\envs\python310\lib\site-packages\llama_index\llms\openai\base.py:36
#      29 from llama_index.core.constants import (
#      30     DEFAULT_TEMPERATURE,
#      31 )
#      32 from llama_index.core.llms.callbacks import (
#      33     llm_chat_callback,
#      34     llm_completion_callback,
#      35 )
# ---> 36 from llama_index.core.llms.generic_utils import (
#      37     achat_to_completion_decorator,
#      38     acompletion_to_chat_decorator,
#      39     astream_chat_to_completion_decorator,
#      40     astream_completion_to_chat_decorator,
#      41     chat_to_completion_decorator,
#      42     completion_to_chat_decorator,
#      43     stream_chat_to_completion_decorator,
#      44     stream_completion_to_chat_decorator,
#      45 )
#      46 from llama_index.core.llms.llm import LLM
#      47 from llama_index.core.types import BaseOutputParser, PydanticProgramMode
#
# ModuleNotFoundError: No module named 'llama_index.core.llms.generic_utils'

# %%
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex
from llama_index.core import Settings
embed_model = OpenAIEmbedding(model="text-embedding-3-small")
llm = OpenAI(model="gpt-3.5-turbo-0125")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from llama_index.embeddings.openai import OpenAIEmbedding
#       2 from llama_index.core import VectorStoreIndex
#       3 from llama_index.core import Settings
#
# File ~\anaconda3\envs\python310\lib\site-packages\llama_index\embeddings\openai\__init__.py:1
# ----> 1 from llama_index.embeddings.openai.base import (
#       2     OpenAIEmbedding,
#       3     OpenAIEmbeddingMode,
#       4     OpenAIEmbeddingModelType,
#       5     OpenAIEmbeddingModeModel,
#       6 )
#       8 __all__ = [
#       9     "OpenAIEmbedding",
#      10     "OpenAIEmbeddingMode",
#      11     "OpenAIEmbeddingModelType",
#      12     "OpenAIEmbeddingModeModel",
#      13 ]
#
# File ~\anaconda3\envs\python310\lib\site-packages\llama_index\embeddings\openai\base.py:10
#       8 from llama_index.core.bridge.pydantic import Field, PrivateAttr
#       9 from llama_index.core.callbacks.base import CallbackManager
# ---> 10 from llama_index.embeddings.openai.utils import (
#      11     create_retry_decorator,
#      12     resolve_openai_credentials,
#      13 )
#      15 from openai import AsyncOpenAI, OpenAI
#      17 embedding_retry_decorator = create_retry_decorator(
#      18     max_retries=6,
#      19     random_exponential=True,
#    (...)
#      22     max_seconds=20,
#      23 )
#
# File ~\anaconda3\envs\python310\lib\site-packages\llama_index\embeddings\openai\utils.py:5
#       2 import os
#       3 from typing import Any, Callable, Optional, Tuple, Union
# ----> 5 from llama_index.core.llms.generic_utils import get_from_param_or_env
#       6 from tenacity import (
#       7     before_sleep_log,
#       8     retry,
#    (...)
#      13     wait_random_exponential,
#      14 )
#      15 from tenacity.stop import stop_base
#
# ModuleNotFoundError: No module named 'llama_index.core.llms.generic_utils'

# %%
Settings.llm = llm
Settings.embed_model = embed_model
